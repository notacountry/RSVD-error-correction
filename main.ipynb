# %%
import numpy as np

from test_matrices import (
    diagonal_known_spectrum,
    exact_low_rank,
    exponential_decay,
    polynomial_decay,
    signal_plus_noise,
)

from benchmark import run_test
from hypothesis_test import run_hypothesis_test

# %%
N     = 5000
K     = 555
P     = 20
SIGMA = np.array([10.0 / (i + 1) for i in range(K)])
SEED  = 42

# polynomial_decay
ALPHA = 1.0

# exponential_decay
BETA = 0.5

# signal_plus_noise
NOISE_LEVEL  = 1.0

# hypothesis test
N_TRIALS   = 100
HT_CONFIGS = [
    # --- correction helps (high noise, low-to-moderate c) ---
    (600,  2, 2.0),
    (600,  3, 2.0),
    (600,  5, 2.0),
    (1000, 2, 5.0),
    (1000, 3, 5.0),
    (1000, 5, 5.0),
    # --- borderline (moderate noise, moderate c) ---
    (600,  3, 1.0),
    (1000, 5, 1.0),
    (1000, 8, 2.0),
    # --- correction hurts (low noise or high c) ---
    (600,  2, 0.5),
    (600,  5, 0.5),
    (600,  8, 2.0),
    (600, 12, 5.0),
    (1000, 12, 5.0),
]

# %%
A, sigma_true = exact_low_rank(n=N, k=K, sigma=SIGMA, seed=SEED)
run_test("Exact low-rank", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Exact low-rank ===
# RSVD RMSE:      4.803118921297393e-16
# Corrected RMSE: 4.803118921297393e-16
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:94: RuntimeWarning: Only 0 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)
# {'name': 'Exact low-rank',
#  'rsvd_rmse': np.float64(4.803118921297393e-16),
#  'corr_rmse': np.float64(4.803118921297393e-16)}

# %%
A, sigma_true = diagonal_known_spectrum(n=N, k=K, sigma=SIGMA, seed=SEED)
run_test("Diagonal known spectrum", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Diagonal known spectrum ===
# RSVD RMSE:      6.389240224646171e-16
# Corrected RMSE: 6.389240224646171e-16
# {'name': 'Diagonal known spectrum',
#  'rsvd_rmse': np.float64(6.389240224646171e-16),
#  'corr_rmse': np.float64(6.389240224646171e-16)}

# %%
A, sigma_true = polynomial_decay(n=N, k=K, alpha=ALPHA, seed=SEED)
run_test("Polynomial decay", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Polynomial decay ===
# RSVD RMSE:      0.0005516379704611772
# Corrected RMSE: 0.0005516379704611772
# {'name': 'Polynomial decay',
#  'rsvd_rmse': np.float64(0.0005516379704611772),
#  'corr_rmse': np.float64(0.0005516379704611772)}

# %%
A, sigma_true = exponential_decay(n=N, k=K, beta=BETA, seed=SEED)
run_test("Exponential decay", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Exponential decay ===
# RSVD RMSE:      8.370994367325151e-17
# Corrected RMSE: 8.370994367325151e-17
# {'name': 'Exponential decay',
#  'rsvd_rmse': np.float64(8.370994367325151e-17),
#  'corr_rmse': np.float64(8.370994367325151e-17)}

# %%
A, sigma_true = signal_plus_noise(n=N, k=K, sigma_signal=SIGMA, noise_level=NOISE_LEVEL, seed=SEED)
run_test("Signal plus noise", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Signal plus noise ===
# RSVD RMSE:      1.29485677446957
# Corrected RMSE: 1.29485677446957
# {'name': 'Signal plus noise',
#  'rsvd_rmse': np.float64(1.29485677446957),
#  'corr_rmse': np.float64(1.29485677446957)}

# %%
run_hypothesis_test(HT_CONFIGS, n_trials=N_TRIALS, p=P)
# Out:
#      N     K     c  noise |      D_bar        s_D        t        p |        CI (-inf, hi) | reject?
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 run_hypothesis_test(HT_CONFIGS, n_trials=N_TRIALS, p=P)
#
# File c:\Users\Student\Documents\Repositories\RSVD-error-correction\hypothesis_test.py:60, in run_hypothesis_test(configs, n_trials, p, alpha)
#      58 warnings.simplefilter("ignore")
#      59 try:
# ---> 60     _, s_plain, _ = rsvd(A, k=K, p=p, seed=seed)
#      61     _, s_corr,  _ = rsvd(A, k=K, p=p, seed=seed, correction=True)
#      62 except Exception:
#
# File c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:53, in rsvd(A, k, p, seed, correction)
#      51 Q, _ = np.linalg.qr(Y, mode="reduced")
#      52 B = Q.T @ A
# ---> 53 U_tilde, Sigma, Vt = np.linalg.svd(B, full_matrices=False)
#      54 U = Q @ U_tilde
#      56 # Truncate
#
# File c:\Users\Student\Documents\Repositories\RSVD-error-correction\venv\Lib\site-packages\numpy\linalg\_linalg.py:1841, in svd(a, full_matrices, compute_uv, hermitian)
#    1837 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
#    1838 with errstate(call=_raise_linalgerror_svd_nonconvergence,
#    1839               invalid='call', over='ignore', divide='ignore',
#    1840               under='ignore'):
# -> 1841     u, s, vh = gufunc(a, signature=signature)
#    1842 u = u.astype(result_t, copy=False)
#    1843 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:
