# %%
import numpy as np

from test_matrices import (
    diagonal_known_spectrum,
    exact_low_rank,
    exponential_decay,
    polynomial_decay,
    signal_plus_noise,
)

from benchmark import run_test
from hypothesis_test import run_hypothesis_test

# %%
N     = 5000
K     = 555
P     = 20
SIGMA = np.array([10.0 / (i + 1) for i in range(K)])
SEED  = 42

# polynomial_decay
ALPHA = 1.0

# exponential_decay
BETA = 0.5

# signal_plus_noise
NOISE_LEVEL  = 1.0

# hypothesis test
N_TRIALS   = 100
HT_CONFIGS = [
    # --- correction helps (high noise, low-to-moderate c) ---
    (600,  2, 2.0),
    (600,  3, 2.0),
    (600,  5, 2.0),
    (1000, 2, 5.0),
    (1000, 3, 5.0),
    (1000, 5, 5.0),
    # --- borderline (moderate noise, moderate c) ---
    (600,  3, 1.0),
    (1000, 5, 1.0),
    (1000, 8, 2.0),
    # --- correction hurts (low noise or high c) ---
    (600,  2, 0.5),
    (600,  5, 0.5),
    (600,  8, 2.0),
    (600, 12, 5.0),
    (1000, 12, 5.0),
]

# %%
A, sigma_true = exact_low_rank(n=N, k=K, sigma=SIGMA, seed=SEED)
run_test("Exact low-rank", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Exact low-rank ===
# RSVD RMSE:      4.803118921297393e-16
# Corrected RMSE: 0.515707325252442
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:97: RuntimeWarning: Only 9 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)
# {'name': 'Exact low-rank',
#  'rsvd_rmse': np.float64(4.803118921297393e-16),
#  'corr_rmse': np.float64(0.515707325252442)}

# %%
A, sigma_true = diagonal_known_spectrum(n=N, k=K, sigma=SIGMA, seed=SEED)
run_test("Diagonal known spectrum", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Diagonal known spectrum ===
# RSVD RMSE:      6.389240224646171e-16
# Corrected RMSE: 0.5188831570714516
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:97: RuntimeWarning: Only 11 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)
# {'name': 'Diagonal known spectrum',
#  'rsvd_rmse': np.float64(6.389240224646171e-16),
#  'corr_rmse': np.float64(0.5188831570714516)}

# %%
A, sigma_true = polynomial_decay(n=N, k=K, alpha=ALPHA, seed=SEED)
run_test("Polynomial decay", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Polynomial decay ===
# RSVD RMSE:      0.0005516379704611772
# Corrected RMSE: 0.05103283697446069
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:97: RuntimeWarning: Only 10 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)
# {'name': 'Polynomial decay',
#  'rsvd_rmse': np.float64(0.0005516379704611772),
#  'corr_rmse': np.float64(0.05103283697446069)}

# %%
A, sigma_true = exponential_decay(n=N, k=K, beta=BETA, seed=SEED)
run_test("Exponential decay", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Exponential decay ===
# RSVD RMSE:      8.370994367325151e-17
# Corrected RMSE: 0.050550370090387146
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:97: RuntimeWarning: Only 6 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)
# {'name': 'Exponential decay',
#  'rsvd_rmse': np.float64(8.370994367325151e-17),
#  'corr_rmse': np.float64(0.050550370090387146)}

# %%
A, sigma_true = signal_plus_noise(n=N, k=K, sigma_signal=SIGMA, noise_level=NOISE_LEVEL, seed=SEED)
run_test("Signal plus noise", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Signal plus noise ===
# RSVD RMSE:      1.29485677446957
# Corrected RMSE: 1.3099212188899074
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:97: RuntimeWarning: Only 7 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)
# {'name': 'Signal plus noise',
#  'rsvd_rmse': np.float64(1.29485677446957),
#  'corr_rmse': np.float64(1.3099212188899074)}

# %%
run_hypothesis_test(HT_CONFIGS, n_trials=N_TRIALS, p=P)
# Out:
#      N     K     c  noise |      D_bar        s_D        t        p |        CI (-inf, hi) | reject?
# ----------------------------------------------------------------------------------------------------
#    600   280  2.00    2.0 |    -0.2132     0.0372  -57.310   0.0000 | (-inf,  -0.2070) |     YES
#    600   180  3.00    2.0 |    -0.2191     0.0565  -38.772   0.0000 | (-inf,  -0.2097) |     YES
#    600   100  5.00    2.0 |    -0.2533     0.1201  -21.092   0.0000 | (-inf,  -0.2334) |     YES
#   1000   480  2.00    5.0 |    -1.6299     0.1228 -132.735   0.0000 | (-inf,  -1.6096) |     YES
#   1000   313  3.00    5.0 |    -1.6661     0.1768  -94.211   0.0000 | (-inf,  -1.6367) |     YES
#   1000   180  5.00    5.0 |    -1.8938     0.5594  -33.853   0.0000 | (-inf,  -1.8010) |     YES
#    600   180  3.00    1.0 |     0.2440     0.0733   33.290   1.0000 | (-inf,   0.2561) |      no
#   1000   180  5.00    1.0 |     0.1914     0.0538   35.589   1.0000 | (-inf,   0.2003) |      no
#   1000   105  8.00    2.0 |    -0.1592     0.1254  -12.696   0.0000 | (-inf,  -0.1384) |     YES
#    600   280  2.00    0.5 |     0.3169     0.0655   48.356   1.0000 | (-inf,   0.3278) |      no
#    600   100  5.00    0.5 |     0.5658     0.3339   16.946   1.0000 | (-inf,   0.6213) |      no
#    600    55  8.00    2.0 |    -0.3091     0.2406  -12.850   0.0000 | (-inf,  -0.2692) |     YES
#    600    30 12.00    5.0 |    -5.5565     3.5781  -15.529   0.0000 | (-inf,  -4.9624) |     YES
#   1000    63 12.05    5.0 |    -2.3372     1.7659  -13.236   0.0000 | (-inf,  -2.0440) |     YES
