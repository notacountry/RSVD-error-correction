# %%
import numpy as np

from test_matrices import (
    diagonal_known_spectrum,
    exact_low_rank,
    exponential_decay,
    polynomial_decay,
    signal_plus_noise,
)

from benchmark import run_test
from hypothesis_test import run_hypothesis_test

# %%
N     = 5000
K     = 555
P     = 20
SIGMA = np.array([10.0 / (i + 1) for i in range(K)])
SEED  = 42

# polynomial_decay
ALPHA = 1.0

# exponential_decay
BETA = 0.5

# signal_plus_noise
NOISE_LEVEL  = 1.0

# hypothesis test
N_TRIALS   = 100
HT_CONFIGS = [
    # --- correction helps (high noise, low-to-moderate c) ---
    (600,  2, 2.0),
    (600,  3, 2.0),
    (600,  5, 2.0),
    (1000, 2, 5.0),
    (1000, 3, 5.0),
    (1000, 5, 5.0),
    # --- borderline (moderate noise, moderate c) ---
    (600,  3, 1.0),
    (1000, 5, 1.0),
    (1000, 8, 2.0),
    # --- correction hurts (low noise or high c) ---
    (600,  2, 0.5),
    (600,  5, 0.5),
    (600,  8, 2.0),
    (600, 12, 5.0),
    (1000, 12, 5.0),
]

# %%
A, sigma_true = exact_low_rank(n=N, k=K, sigma=SIGMA, seed=SEED)
run_test("Exact low-rank", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Exact low-rank ===
# RSVD RMSE:      4.803118921297393e-16
# Corrected RMSE: 0.5219393169189975
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:84: RuntimeWarning: Only 11 of 555 requested eigenvalues were recovered.
#   sigma_corr  = np.sqrt(S_inverse(w, S_A, k))
# {'name': 'Exact low-rank',
#  'rsvd_rmse': np.float64(4.803118921297393e-16),
#  'corr_rmse': np.float64(0.5219393169189975)}

# %%
A, sigma_true = diagonal_known_spectrum(n=N, k=K, sigma=SIGMA, seed=SEED)
run_test("Diagonal known spectrum", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Diagonal known spectrum ===
# RSVD RMSE:      6.389240224646171e-16
# Corrected RMSE: 0.5225976930145216
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:84: RuntimeWarning: Only 13 of 555 requested eigenvalues were recovered.
#   sigma_corr  = np.sqrt(S_inverse(w, S_A, k))
# {'name': 'Diagonal known spectrum',
#  'rsvd_rmse': np.float64(6.389240224646171e-16),
#  'corr_rmse': np.float64(0.5225976930145216)}

# %%
A, sigma_true = polynomial_decay(n=N, k=K, alpha=ALPHA, seed=SEED)
run_test("Polynomial decay", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Polynomial decay ===
# RSVD RMSE:      0.0005516379704611772
# Corrected RMSE: 0.051327284212244535
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:84: RuntimeWarning: Only 14 of 555 requested eigenvalues were recovered.
#   sigma_corr  = np.sqrt(S_inverse(w, S_A, k))
# {'name': 'Polynomial decay',
#  'rsvd_rmse': np.float64(0.0005516379704611772),
#  'corr_rmse': np.float64(0.051327284212244535)}

# %%
A, sigma_true = exponential_decay(n=N, k=K, beta=BETA, seed=SEED)
run_test("Exponential decay", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Exponential decay ===
# RSVD RMSE:      8.370994367325151e-17
# Corrected RMSE: 8.370994367325151e-17
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:84: RuntimeWarning: Only 0 of 555 requested eigenvalues were recovered.
#   sigma_corr  = np.sqrt(S_inverse(w, S_A, k))
# {'name': 'Exponential decay',
#  'rsvd_rmse': np.float64(8.370994367325151e-17),
#  'corr_rmse': np.float64(8.370994367325151e-17)}

# %%
A, sigma_true = signal_plus_noise(n=N, k=K, sigma_signal=SIGMA, noise_level=NOISE_LEVEL, seed=SEED)
run_test("Signal plus noise", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Signal plus noise ===
# RSVD RMSE:      1.29485677446957
# Corrected RMSE: 1.3118703420390816
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:84: RuntimeWarning: Only 7 of 555 requested eigenvalues were recovered.
#   sigma_corr  = np.sqrt(S_inverse(w, S_A, k))
# {'name': 'Signal plus noise',
#  'rsvd_rmse': np.float64(1.29485677446957),
#  'corr_rmse': np.float64(1.3118703420390816)}

# %%
run_hypothesis_test(HT_CONFIGS, n_trials=N_TRIALS, p=P)
# Out:
#      N     K     c  noise |      D_bar        s_D        t        p |        CI (-inf, hi) | reject?
# ----------------------------------------------------------------------------------------------------
#    600   280  2.00    2.0 |    -0.2188     0.0370  -59.179   0.0000 | (-inf,  -0.2126) |     YES
