# %%
import numpy as np

from test_matrices import (
    diagonal_known_spectrum,
    exact_low_rank,
    exponential_decay,
    polynomial_decay,
    run_test,
    signal_plus_noise,
)

from hypothesis_test import run_hypothesis_test

# %%
N     = 5000
K     = 555
P     = 20
SIGMA = np.array([10.0 / (i + 1) for i in range(K)])
SEED  = 42

# polynomial_decay
ALPHA = 1.0

# exponential_decay
BETA = 0.5

# signal_plus_noise
NOISE_LEVEL  = 1.0

# hypothesis test
N_TRIALS   = 100
HT_CONFIGS = [
    # --- correction helps (high noise, low-to-moderate c) ---
    (600,  2, 2.0),
    (600,  3, 2.0),
    (600,  5, 2.0),
    (1000, 2, 5.0),
    (1000, 3, 5.0),
    (1000, 5, 5.0),
    # --- borderline (moderate noise, moderate c) ---
    (600,  3, 1.0),
    (1000, 5, 1.0),
    (1000, 8, 2.0),
    # --- correction hurts (low noise or high c) ---
    (600,  2, 0.5),
    (600,  5, 0.5),
    (600,  8, 2.0),
    (600, 12, 5.0),
    (1000, 12, 5.0),
]

# %%
A, sigma_true = exact_low_rank(n=N, k=K, sigma=SIGMA, seed=SEED)
run_test("Exact low-rank", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Exact low-rank ===
# RSVD error:      1.1315397921208689e-14
# Corrected error: 8.69736861907178
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:137: RuntimeWarning: Only 13 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)

# %%
A, sigma_true = diagonal_known_spectrum(n=N, k=K, sigma=SIGMA, seed=SEED)
run_test("Diagonal known spectrum", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Diagonal known spectrum ===
# RSVD error:      1.5052051956384997e-14
# Corrected error: 8.455189303582008
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:137: RuntimeWarning: Only 11 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)

# %%
A, sigma_true = polynomial_decay(n=N, k=K, alpha=ALPHA, seed=SEED)
run_test("Polynomial decay", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Polynomial decay ===
# RSVD error:      0.012995728913849439
# Corrected error: 0.9100634518574778
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:137: RuntimeWarning: Only 12 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)

# %%
A, sigma_true = exponential_decay(n=N, k=K, beta=BETA, seed=SEED)
run_test("Exponential decay", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Exponential decay ===
# RSVD error:      1.9720755162334194e-15
# Corrected error: 1.1883015746770644
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:137: RuntimeWarning: Only 6 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)

# %%
A, sigma_true = signal_plus_noise(n=N, k=K, sigma_signal=SIGMA, noise_level=NOISE_LEVEL, seed=SEED)
run_test("Signal plus noise", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Signal plus noise ===
# RSVD error:      30.50480301274383
# Corrected error: 30.61094240243896
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:137: RuntimeWarning: Only 5 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)

# %%
run_hypothesis_test(HT_CONFIGS, n_trials=N_TRIALS, p=P)
# Out:
#      N     K     c  noise |      D_bar        s_D        t        p |        CI (-inf, hi) | reject?
# ----------------------------------------------------------------------------------------------------
#    600   280  2.00    2.0 |    -0.0141     0.0101  -13.939   0.0000 | (-inf,  -0.0124) |     YES
#    600   180  3.00    2.0 |     0.0197     0.0514    3.827   0.9999 | (-inf,   0.0282) |      no
