# %%
import numpy as np

from test_matrices import (
    diagonal_known_spectrum,
    exact_low_rank,
    exponential_decay,
    polynomial_decay,
    run_test,
    signal_plus_noise,
)

from hypothesis_test import run_hypothesis_test

# %%
N     = 5000
K     = 555
P     = 20
SIGMA = np.array([10.0 / (i + 1) for i in range(K)])
SEED  = 42

# polynomial_decay
ALPHA = 1.0

# exponential_decay
BETA = 0.5

# signal_plus_noise
NOISE_LEVEL  = 1.0

# hypothesis test
N_TRIALS   = 100
HT_CONFIGS = [
    # --- correction helps (high noise, low-to-moderate c) ---
    (600,  2, 2.0),
    (600,  3, 2.0),
    (600,  5, 2.0),
    (1000, 2, 5.0),
    (1000, 3, 5.0),
    (1000, 5, 5.0),
    # --- borderline (moderate noise, moderate c) ---
    (600,  3, 1.0),
    (1000, 5, 1.0),
    (1000, 8, 2.0),
    # --- correction hurts (low noise or high c) ---
    (600,  2, 0.5),
    (600,  5, 0.5),
    (600,  8, 2.0),
    (600, 12, 5.0),
    (1000, 12, 5.0),
]

# %%
A, sigma_true = exact_low_rank(n=N, k=K, sigma=SIGMA, seed=SEED)
run_test("Exact low-rank", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Exact low-rank ===
# RSVD error:      1.1315397921208689e-14
# Corrected error: 12.299494023200168
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:131: RuntimeWarning: Only 10 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)

# %%
A, sigma_true = diagonal_known_spectrum(n=N, k=K, sigma=SIGMA, seed=SEED)
run_test("Diagonal known spectrum", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Diagonal known spectrum ===
# RSVD error:      1.5052051956384997e-14
# Corrected error: 12.150569141891522

# %%
A, sigma_true = polynomial_decay(n=N, k=K, alpha=ALPHA, seed=SEED)
run_test("Polynomial decay", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Polynomial decay ===
# RSVD error:      0.012995728913849439
# Corrected error: 1.2219008632277717

# %%
A, sigma_true = exponential_decay(n=N, k=K, beta=BETA, seed=SEED)
run_test("Exponential decay", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Exponential decay ===
# RSVD error:      1.9720755162334194e-15
# Corrected error: 1.1148514185876652
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:131: RuntimeWarning: Only 12 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)

# %%
A, sigma_true = signal_plus_noise(n=N, k=K, sigma_signal=SIGMA, noise_level=NOISE_LEVEL, seed=SEED)
run_test("Signal plus noise", A, sigma_true, k=K, p=P, seed=SEED)
# Out:
# === Signal plus noise ===
# RSVD error:      30.50480301274383
# Corrected error: 30.476893861249298
# c:\Users\Student\Documents\Repositories\RSVD-error-correction\rsvd.py:131: RuntimeWarning: Only 17 of 555 requested eigenvalues were recovered.
#   lambda_corr = S_inverse(w, S_A, k)

# %%
run_hypothesis_test(HT_CONFIGS, n_trials=N_TRIALS, p=P)
# Out:
#      N     K     c  noise |      D_bar        s_D        t        p |        CI (-inf, hi) | reject?
# ----------------------------------------------------------------------------------------------------
#    600   280  2.00    2.0 |    -0.3790     0.0552  -68.622   0.0000 | (-inf,  -0.3698) |     YES
#    600   180  3.00    2.0 |    -0.4094     0.0732  -55.922   0.0000 | (-inf,  -0.3972) |     YES
#    600   100  5.00    2.0 |    -0.4882     0.2072  -23.557   0.0000 | (-inf,  -0.4538) |     YES
#   1000   480  2.00    5.0 |    -2.1143     0.1076 -196.523   0.0000 | (-inf,  -2.0965) |     YES
#   1000   313  3.00    5.0 |    -2.2853     0.2784  -82.096   0.0000 | (-inf,  -2.2391) |     YES
#   1000   180  5.00    5.0 |    -2.3871     0.6981  -34.193   0.0000 | (-inf,  -2.2712) |     YES
#    600   180  3.00    1.0 |     0.1265     0.1275    9.920   1.0000 | (-inf,   0.1477) |      no
#   1000   180  5.00    1.0 |    -0.0074     0.0076   -9.740   0.0000 | (-inf,  -0.0061) |     YES
#   1000   105  8.00    2.0 |    -0.2459     0.1341  -18.341   0.0000 | (-inf,  -0.2236) |     YES
#    600   280  2.00    0.5 |     0.2529     0.1596   15.846   1.0000 | (-inf,   0.2794) |      no
#    600   100  5.00    0.5 |     0.4224     0.2031   20.800   1.0000 | (-inf,   0.4561) |      no
#    600    55  8.00    2.0 |    -0.3480     0.3676   -9.466   0.0000 | (-inf,  -0.2869) |     YES
#    600    30 12.00    5.0 |    30.8051     7.0014   43.999   1.0000 | (-inf,  31.9676) |      no
#   1000    63 12.05    5.0 |    15.0841     8.8463   17.051   1.0000 | (-inf,  16.5529) |      no
